# %%
# %run "../../../setup.ipynb"
if CLIENT == None:
    print("Failed to create CLIENT.")
# Out:
# Setup Complete. Use CLIENT to access Weaviate.

# %%
import pandas as pd

# Load the data from the new CSV file
data = pd.read_pickle("../../../data/data.pkl")

# Display the first few rows of the data
data.head()
# Out:
#          accession_number alternate_title api_model  catalog_key  \
# 0  Voyager:inudilcsmi3443             NaN      Work          NaN
# 1  Voyager:inudilcsmi2411             NaN      Work          NaN
# 2   Voyager:inudilcsmi287             NaN      Work          NaN
# 3  Voyager:inudilcsmi1617             NaN      Work          NaN
# 4   Voyager:inudilcsmi460             NaN      Work          NaN
#
#                  collection       contributor                  create_date  \
# 0  Collection of Carl Smith  [Smith, Carl S.]  2021-03-15T15:31:05.675248Z
# 1  Collection of Carl Smith  [Smith, Carl S.]  2021-03-15T15:31:16.551184Z
# 2  Collection of Carl Smith  [Smith, Carl S.]  2021-03-15T15:31:20.237074Z
# 3  Collection of Carl Smith  [Smith, Carl S.]  2021-03-15T15:31:45.369596Z
# 4  Collection of Carl Smith  [Smith, Carl S.]  2021-03-15T15:31:50.543643Z
#
#      creator    date_created date_created_edtf  ...  \
# 0  [unknown]  [1967 to 1999]       [1967/1999]  ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the missing values in each column
missing_values = data.isnull()

# Plot a heatmap of the missing values
plt.figure(figsize=(10, 6))
sns.heatmap(~missing_values, cbar=False, yticklabels=False)
plt.title("Data Completeness Heatmap (Black: Data, White: Missing)", fontsize=13)
plt.show()
